# %% [markdown]
# <a href="https://colab.research.google.com/github/thdefn/AIproj2022/blob/master/1130_nongenCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

from tensorflow import keras

from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras.layers import Dropout, BatchNormalization 
from tensorflow.keras.utils import to_categorical

# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.callbacks import ModelCheckpoint

import matplotlib.pyplot as plt

import seaborn as sns
import os
import glob
import plotly.graph_objects as go
import cv2
from PIL import Image
from PIL import ImageFile
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop,Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau,ModelCheckpoint 
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import warnings
warnings.filterwarnings("ignore")
ImageFile.LOAD_TRUNCATED_IMAGES = True

from tqdm import tqdm

# %%
X_valid = np.load('/kaggle/input/myimggen/X_valid_128.npy',allow_pickle=True)
y_valid = np.load('/kaggle/input/myimggen/y_valid_128.npy',allow_pickle=True)
X_train = np.load('/kaggle/input/myimggen/X_train_128.npy',allow_pickle=True)
y_train = np.load('/kaggle/input/myimggen/y_train_128.npy',allow_pickle=True)
X_test = np.load('/kaggle/input/myimggen/X_test_128.npy',allow_pickle=True)
y_test = np.load('/kaggle/input/myimggen/y_test_128.npy',allow_pickle=True)


X_train = X_train/255
X_valid = X_valid/255
X_test = X_test/255

le = LabelEncoder().fit(['Type 1', 'Type 2', 'Type 3'])
y_train = le.transform(y_train)
y_valid = le.transform(y_valid)

y_train_onehot = to_categorical(y_train, num_classes=3)
y_valid_onehot = to_categorical(y_valid, num_classes=3)

# %%
BATCH_SIZE = 16
TRAIN_STEPS = len(X_train)//BATCH_SIZE
VAL_STEPS = len(X_valid)//BATCH_SIZE
t = ImageDataGenerator(rotation_range=0.3, zoom_range=0.3)
k = ImageDataGenerator()
valid_gen = t.flow(X_valid, y_valid_onehot, batch_size = BATCH_SIZE)
train_gen = t.flow(X_train, y_train_onehot, batch_size = BATCH_SIZE)
valid_ngen = k.flow(X_valid, y_valid_onehot, batch_size = BATCH_SIZE)
train_ngen = k.flow(X_train, y_train_onehot, batch_size = BATCH_SIZE)

# %%
reduceLR = ReduceLROnPlateau(monitor='val_accuracy', patience=10, verbose= 1, mode='max', factor=  0.2, min_lr = 1e-5)

early_stopping = EarlyStopping(monitor='val_accuracy', patience = 20, verbose=1, mode='max', restore_best_weights= True)

checkpoint_ag = ModelCheckpoint('cnn_v2_ag.weights.hdf5', monitor='val_accuracy', verbose=1,save_best_only=True, mode= 'max')

# %%
cnn = Sequential([
    Conv2D(64, kernel_size = (3,3), padding='same', kernel_initializer='random_normal', input_shape=(128,128,3)),
    Activation('relu'),
    MaxPooling2D(pool_size=(2,2)),
    
    Conv2D(32, kernel_size = (3,3), padding='same', kernel_initializer='random_normal'),
    Activation('relu'),
    MaxPooling2D(pool_size=(2,2)),
    
    Conv2D(64, kernel_size = (3,3), padding='same', kernel_initializer='random_normal'),
    Activation('relu'),
    MaxPooling2D(pool_size=(2,2)),

    Flatten(),
    Dense(64, kernel_initializer='random_normal'),
    Activation('relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')
    
])

cnn.summary()
# Out:
# 2022-11-30 02:37:53.571625: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 64)      1792
# _________________________________________________________________
# activation (Activation)      (None, 128, 128, 64)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        18464
# _________________________________________________________________
# activation_1 (Activation)    (None, 64, 64, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                1048640
# _________________________________________________________________
# activation_3 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 1,087,587
# Trainable params: 1,087,587
# Non-trainable params: 0
# _________________________________________________________________
# 2022-11-30 02:37:53.705883: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-30 02:37:53.706763: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-30 02:37:53.708011: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-30 02:37:53.716587: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-30 02:37:53.717304: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-30 02:37:53.718013: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-30 02:37:55.970424: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-30 02:37:55.971436: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-30 02:37:55.972348: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-30 02:37:55.972991: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
cnn.compile(
  optimizer= SGD(lr=0.01, momentum=0.9),
  loss='categorical_crossentropy',
  metrics=['accuracy'],
)

# %%
general = cnn.fit(train_ngen, validation_data= valid_ngen, epochs= 100, verbose=1,  steps_per_epoch = TRAIN_STEPS,  callbacks = [reduceLR, early_stopping, checkpoint_ag])
cnn.save('CNNnon_1130.h5')
# Out:
# Epoch 1/100
# 2022-11-30 02:37:56.539398: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-11-30 02:37:57.855400: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 410/410 [==============================] - 11s 10ms/step - loss: 1.0116 - accuracy: 0.5256 - val_loss: 1.0005 - val_accuracy: 0.5295
#
# Epoch 00001: val_accuracy improved from -inf to 0.52952, saving model to cnn_v2_ag.weights.hdf5
# Epoch 2/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.9903 - accuracy: 0.5259 - val_loss: 0.9710 - val_accuracy: 0.5295
#
# Epoch 00002: val_accuracy did not improve from 0.52952
# Epoch 3/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.9811 - accuracy: 0.5301 - val_loss: 0.9788 - val_accuracy: 0.5295
#
# Epoch 00003: val_accuracy did not improve from 0.52952
# Epoch 4/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.9811 - accuracy: 0.5285 - val_loss: 0.9712 - val_accuracy: 0.5295
#
# Epoch 00004: val_accuracy did not improve from 0.52952
# Epoch 5/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.9786 - accuracy: 0.5286 - val_loss: 0.9659 - val_accuracy: 0.5460
#
# Epoch 00005: val_accuracy improved from 0.52952 to 0.54595, saving model to cnn_v2_ag.weights.hdf5
# Epoch 6/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.9742 - accuracy: 0.5277 - val_loss: 0.9661 - val_accuracy: 0.5295
#
# Epoch 00006: val_accuracy did not improve from 0.54595
# Epoch 7/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.9716 - accuracy: 0.5291 - val_loss: 0.9627 - val_accuracy: 0.5380
#
# Epoch 00007: val_accuracy did not improve from 0.54595
# Epoch 8/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.9720 - accuracy: 0.5304 - val_loss: 0.9581 - val_accuracy: 0.5386
#
# Epoch 00008: val_accuracy did not improve from 0.54595
# Epoch 9/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.9676 - accuracy: 0.5256 - val_loss: 0.9575 - val_accuracy: 0.5514
#
# Epoch 00009: val_accuracy improved from 0.54595 to 0.55143, saving model to cnn_v2_ag.weights.hdf5
# Epoch 10/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.9654 - accuracy: 0.5326 - val_loss: 0.9570 - val_accuracy: 0.5344
#
# Epoch 00010: val_accuracy did not improve from 0.55143
# Epoch 11/100
# 410/410 [==============================] - 4s 10ms/step - loss: 0.9573 - accuracy: 0.5358 - val_loss: 0.9479 - val_accuracy: 0.5514
#
# Epoch 00011: val_accuracy did not improve from 0.55143
# Epoch 12/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.9554 - accuracy: 0.5369 - val_loss: 0.9527 - val_accuracy: 0.5332
#
# Epoch 00012: val_accuracy did not improve from 0.55143
# Epoch 13/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.9530 - accuracy: 0.5353 - val_loss: 0.9493 - val_accuracy: 0.5417
#
# Epoch 00013: val_accuracy did not improve from 0.55143
# Epoch 14/100
# 410/410 [==============================] - 4s 10ms/step - loss: 0.9450 - accuracy: 0.5419 - val_loss: 0.9349 - val_accuracy: 0.5447
#
# Epoch 00014: val_accuracy did not improve from 0.55143
# Epoch 15/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.9377 - accuracy: 0.5436 - val_loss: 0.9373 - val_accuracy: 0.5478
#
# Epoch 00015: val_accuracy did not improve from 0.55143
# Epoch 16/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.9255 - accuracy: 0.5481 - val_loss: 0.9417 - val_accuracy: 0.5539
#
# Epoch 00016: val_accuracy improved from 0.55143 to 0.55386, saving model to cnn_v2_ag.weights.hdf5
# Epoch 17/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.9249 - accuracy: 0.5460 - val_loss: 0.9331 - val_accuracy: 0.5520
#
# Epoch 00017: val_accuracy did not improve from 0.55386
# Epoch 18/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.9125 - accuracy: 0.5594 - val_loss: 0.9561 - val_accuracy: 0.5460
#
# Epoch 00018: val_accuracy did not improve from 0.55386
# Epoch 19/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.8988 - accuracy: 0.5636 - val_loss: 0.9541 - val_accuracy: 0.5301
#
# Epoch 00019: val_accuracy did not improve from 0.55386
# Epoch 20/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.8871 - accuracy: 0.5767 - val_loss: 0.9387 - val_accuracy: 0.5435
#
# Epoch 00020: val_accuracy did not improve from 0.55386
# Epoch 21/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.8673 - accuracy: 0.5869 - val_loss: 0.9461 - val_accuracy: 0.5520
#
# Epoch 00021: val_accuracy did not improve from 0.55386
# Epoch 22/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.8544 - accuracy: 0.5933 - val_loss: 0.9345 - val_accuracy: 0.5569
#
# Epoch 00022: val_accuracy improved from 0.55386 to 0.55691, saving model to cnn_v2_ag.weights.hdf5
# Epoch 23/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.8261 - accuracy: 0.6005 - val_loss: 0.9233 - val_accuracy: 0.5673
#
# Epoch 00023: val_accuracy improved from 0.55691 to 0.56726, saving model to cnn_v2_ag.weights.hdf5
# Epoch 24/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.8136 - accuracy: 0.6095 - val_loss: 0.9270 - val_accuracy: 0.5642
#
# Epoch 00024: val_accuracy did not improve from 0.56726
# Epoch 25/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.7941 - accuracy: 0.6219 - val_loss: 0.9294 - val_accuracy: 0.5600
#
# Epoch 00025: val_accuracy did not improve from 0.56726
# Epoch 26/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.7997 - accuracy: 0.6246 - val_loss: 0.9274 - val_accuracy: 0.5861
#
# Epoch 00026: val_accuracy improved from 0.56726 to 0.58612, saving model to cnn_v2_ag.weights.hdf5
# Epoch 27/100
# 410/410 [==============================] - 4s 10ms/step - loss: 0.7691 - accuracy: 0.6377 - val_loss: 0.9206 - val_accuracy: 0.5782
#
# Epoch 00027: val_accuracy did not improve from 0.58612
# Epoch 28/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.7571 - accuracy: 0.6431 - val_loss: 0.9322 - val_accuracy: 0.5879
#
# Epoch 00028: val_accuracy improved from 0.58612 to 0.58795, saving model to cnn_v2_ag.weights.hdf5
# Epoch 29/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.7318 - accuracy: 0.6599 - val_loss: 0.9820 - val_accuracy: 0.5703
#
# Epoch 00029: val_accuracy did not improve from 0.58795
# Epoch 30/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.7130 - accuracy: 0.6650 - val_loss: 1.0523 - val_accuracy: 0.5764
#
# Epoch 00030: val_accuracy did not improve from 0.58795
# Epoch 31/100
# 410/410 [==============================] - 4s 10ms/step - loss: 0.6962 - accuracy: 0.6760 - val_loss: 0.9620 - val_accuracy: 0.5843
#
# Epoch 00031: val_accuracy did not improve from 0.58795
# Epoch 32/100
# 410/410 [==============================] - 4s 10ms/step - loss: 0.6936 - accuracy: 0.6788 - val_loss: 0.9732 - val_accuracy: 0.5867
#
# Epoch 00032: val_accuracy did not improve from 0.58795
# Epoch 33/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.6678 - accuracy: 0.6908 - val_loss: 1.0219 - val_accuracy: 0.5849
#
# Epoch 00033: val_accuracy did not improve from 0.58795
# Epoch 34/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.6581 - accuracy: 0.6930 - val_loss: 0.9966 - val_accuracy: 0.5691
#
# Epoch 00034: val_accuracy did not improve from 0.58795
# Epoch 35/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.6532 - accuracy: 0.6966 - val_loss: 1.0400 - val_accuracy: 0.5642
#
# Epoch 00035: val_accuracy did not improve from 0.58795
# Epoch 36/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.6166 - accuracy: 0.7172 - val_loss: 1.0644 - val_accuracy: 0.5679
#
# Epoch 00036: val_accuracy did not improve from 0.58795
# Epoch 37/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.6293 - accuracy: 0.7152 - val_loss: 1.0696 - val_accuracy: 0.5776
#
# Epoch 00037: val_accuracy did not improve from 0.58795
# Epoch 38/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.6366 - accuracy: 0.7159 - val_loss: 1.0178 - val_accuracy: 0.5794
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
#
# Epoch 00038: val_accuracy did not improve from 0.58795
# Epoch 39/100
# 410/410 [==============================] - 4s 10ms/step - loss: 0.5436 - accuracy: 0.7471 - val_loss: 1.0665 - val_accuracy: 0.5904
#
# Epoch 00039: val_accuracy improved from 0.58795 to 0.59038, saving model to cnn_v2_ag.weights.hdf5
# Epoch 40/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.4936 - accuracy: 0.7734 - val_loss: 1.1162 - val_accuracy: 0.5928
#
# Epoch 00040: val_accuracy improved from 0.59038 to 0.59282, saving model to cnn_v2_ag.weights.hdf5
# Epoch 41/100
# 410/410 [==============================] - 4s 10ms/step - loss: 0.4867 - accuracy: 0.7803 - val_loss: 1.1490 - val_accuracy: 0.6056
#
# Epoch 00041: val_accuracy improved from 0.59282 to 0.60560, saving model to cnn_v2_ag.weights.hdf5
# Epoch 42/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.4643 - accuracy: 0.7803 - val_loss: 1.1705 - val_accuracy: 0.6001
#
# Epoch 00042: val_accuracy did not improve from 0.60560
# Epoch 43/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.4564 - accuracy: 0.7897 - val_loss: 1.2063 - val_accuracy: 0.6019
#
# Epoch 00043: val_accuracy did not improve from 0.60560
# Epoch 44/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.4358 - accuracy: 0.8036 - val_loss: 1.2395 - val_accuracy: 0.5959
#
# Epoch 00044: val_accuracy did not improve from 0.60560
# Epoch 45/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.4233 - accuracy: 0.8042 - val_loss: 1.2731 - val_accuracy: 0.6019
#
# Epoch 00045: val_accuracy did not improve from 0.60560
# Epoch 46/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.4113 - accuracy: 0.8083 - val_loss: 1.3047 - val_accuracy: 0.5977
#
# Epoch 00046: val_accuracy did not improve from 0.60560
# Epoch 47/100
# 410/410 [==============================] - 4s 10ms/step - loss: 0.4071 - accuracy: 0.8143 - val_loss: 1.3509 - val_accuracy: 0.5989
#
# Epoch 00047: val_accuracy did not improve from 0.60560
# Epoch 48/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.4030 - accuracy: 0.8166 - val_loss: 1.3710 - val_accuracy: 0.6026
#
# Epoch 00048: val_accuracy did not improve from 0.60560
# Epoch 49/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.4064 - accuracy: 0.8100 - val_loss: 1.3696 - val_accuracy: 0.5953
#
# Epoch 00049: val_accuracy did not improve from 0.60560
# Epoch 50/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.3860 - accuracy: 0.8183 - val_loss: 1.4314 - val_accuracy: 0.6056
#
# Epoch 00050: val_accuracy did not improve from 0.60560
# Epoch 51/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.3844 - accuracy: 0.8236 - val_loss: 1.4552 - val_accuracy: 0.6044
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
#
# Epoch 00051: val_accuracy did not improve from 0.60560
# Epoch 52/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.3649 - accuracy: 0.8317 - val_loss: 1.4399 - val_accuracy: 0.6026
#
# Epoch 00052: val_accuracy did not improve from 0.60560
# Epoch 53/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.3671 - accuracy: 0.8294 - val_loss: 1.4370 - val_accuracy: 0.6026
#
# Epoch 00053: val_accuracy did not improve from 0.60560
# Epoch 54/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.3548 - accuracy: 0.8349 - val_loss: 1.4446 - val_accuracy: 0.5959
#
# Epoch 00054: val_accuracy did not improve from 0.60560
# Epoch 55/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.3510 - accuracy: 0.8382 - val_loss: 1.4878 - val_accuracy: 0.5953
#
# Epoch 00055: val_accuracy did not improve from 0.60560
# Epoch 56/100
# 410/410 [==============================] - 4s 10ms/step - loss: 0.3490 - accuracy: 0.8372 - val_loss: 1.5046 - val_accuracy: 0.5959
#
# Epoch 00056: val_accuracy did not improve from 0.60560
# Epoch 57/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.3534 - accuracy: 0.8346 - val_loss: 1.5099 - val_accuracy: 0.5910
#
# Epoch 00057: val_accuracy did not improve from 0.60560
# Epoch 58/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.3451 - accuracy: 0.8352 - val_loss: 1.5467 - val_accuracy: 0.5934
#
# Epoch 00058: val_accuracy did not improve from 0.60560
# Epoch 59/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.3418 - accuracy: 0.8422 - val_loss: 1.5559 - val_accuracy: 0.5977
#
# Epoch 00059: val_accuracy did not improve from 0.60560
# Epoch 60/100
# 410/410 [==============================] - 4s 9ms/step - loss: 0.3432 - accuracy: 0.8327 - val_loss: 1.5431 - val_accuracy: 0.5965
#
# Epoch 00060: val_accuracy did not improve from 0.60560
# Epoch 61/100
# 410/410 [==============================] - 4s 10ms/step - loss: 0.3429 - accuracy: 0.8405 - val_loss: 1.5809 - val_accuracy: 0.5922
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 7.999999215826393e-05.
# Restoring model weights from the end of the best epoch.
#
# Epoch 00061: val_accuracy did not improve from 0.60560
# Epoch 00061: early stopping

# %%
general.history
# Out:
# {'loss': [1.011589527130127,
#   0.9902722835540771,
#   0.9810906052589417,
#   0.9811050891876221,
#   0.9785546064376831,
#   0.9742305278778076,
#   0.9716162085533142,
#   0.9719616174697876,
#   0.9676483869552612,
#   0.9654044508934021,
#   0.9573394060134888,
#   0.9554235935211182,
#   0.9529549479484558,
#   0.9450153708457947,
#   0.9377198219299316,
#   0.9254812598228455,
#   0.9249324202537537,
#   0.9125035405158997,
#   0.8988066911697388,
#   0.8870701789855957,
#   0.8672974705696106,
#   0.8544325828552246,
#   0.8261216282844543,
#   0.8135512471199036,
#   0.794127881526947,
#   0.7996629476547241,
#   0.7690905332565308,
#   0.7571207880973816,
#   0.7318164706230164,
#   0.7129937410354614,
#   0.6962348222732544,
#   0.6935709714889526,
#   0.6678242683410645,
#   0.6581314206123352,
#   0.6532107591629028,
#   0.6166247725486755,
#   0.6293068528175354,
#   0.6365710496902466,
#   0.5435965657234192,
#   0.4935803711414337,
#   0.48669010400772095,
#   0.4643368721008301,
#   0.45641982555389404,
#   0.4358299970626831,
#   0.4233447015285492,
#   0.41133877635002136,
#   0.4071081578731537,
#   0.40300434827804565,
#   0.4064439833164215,
#   0.3860180079936981,
#   0.3844040036201477,
#   0.36486271023750305,
#   0.36707037687301636,
#   0.35476502776145935,
#   0.35102108120918274,
#   0.34896767139434814,
#   0.3533894419670105,
#   0.34512412548065186,
#   0.34176138043403625,
#   0.3432309329509735,
#   0.3428947925567627],
#  'accuracy': [0.5255607962608337,
#   0.5258660316467285,
#   0.5301388502120972,
#   0.5284602642059326,
#   0.5286128520965576,
#   0.5276972651481628,
#   0.5290706753730774,
#   0.5304440855979919,
#   0.5255607962608337,
#   0.5325804948806763,
#   0.5357851386070251,
#   0.5368533730506897,
#   0.5353273153305054,
#   0.5418891906738281,
#   0.5435678362846375,
#   0.5481458902359009,
#   0.5460094809532166,
#   0.5594384074211121,
#   0.5635586977005005,
#   0.576682448387146,
#   0.5869067311286926,
#   0.5933160185813904,
#   0.6004883050918579,
#   0.6094918251037598,
#   0.6218525767326355,
#   0.6245993971824646,
#   0.6377232074737549,
#   0.6430642604827881,
#   0.6598504781723022,
#   0.6650388836860657,
#   0.6760262250900269,
#   0.6787731051445007,
#   0.6908286213874817,
#   0.692965030670166,
#   0.6966274976730347,
#   0.7172287702560425,
#   0.7152449488639832,
#   0.7158553600311279,
#   0.7471387386322021,
#   0.7733862400054932,
#   0.7802532911300659,
#   0.7802532911300659,
#   0.7897146344184875,
#   0.8036013841629028,
#   0.8042117953300476,
#   0.808332085609436,
#   0.814283549785614,
#   0.8165725469589233,
#   0.8100106716156006,
#   0.8182511925697327,
#   0.8235922455787659,
#   0.8316801190376282,
#   0.8293911218643188,
#   0.834884762763977,
#   0.8382420539855957,
#   0.8371738195419312,
#   0.834579586982727,
#   0.8351899981498718,
#   0.8422096967697144,
#   0.8327483534812927,
#   0.840531051158905],
#  'val_loss': [1.0004827976226807,
#   0.970967710018158,
#   0.9787978529930115,
#   0.971200168132782,
#   0.9658752679824829,
#   0.9660887718200684,
#   0.9626868367195129,
#   0.9580942988395691,
#   0.9575415849685669,
#   0.9570233821868896,
#   0.9479043483734131,
#   0.9526530504226685,
#   0.9492590427398682,
#   0.9349483251571655,
#   0.9372593760490417,
#   0.9417161345481873,
#   0.9330719113349915,
#   0.9560577273368835,
#   0.9541407823562622,
#   0.9386971592903137,
#   0.9460974335670471,
#   0.9345304369926453,
#   0.9232681393623352,
#   0.927028238773346,
#   0.929449737071991,
#   0.9274022579193115,
#   0.9206005334854126,
#   0.9321637749671936,
#   0.9819688200950623,
#   1.0523101091384888,
#   0.9620097279548645,
#   0.9731596112251282,
#   1.021868109703064,
#   0.9966179132461548,
#   1.0399597883224487,
#   1.0643812417984009,
#   1.0696158409118652,
#   1.0178048610687256,
#   1.0665425062179565,
#   1.116160273551941,
#   1.148959994316101,
#   1.17054283618927,
#   1.206343650817871,
#   1.239532232284546,
#   1.2731218338012695,
#   1.3047417402267456,
#   1.3509396314620972,
#   1.3709949254989624,
#   1.369560718536377,
#   1.4313879013061523,
#   1.4551807641983032,
#   1.4398984909057617,
#   1.4370436668395996,
#   1.4446097612380981,
#   1.4877936840057373,
#   1.5046284198760986,
#   1.5099493265151978,
#   1.5466818809509277,
#   1.5558953285217285,
#   1.5431151390075684,
#   1.5809335708618164],
#  'val_accuracy': [0.5295192003250122,
#   0.5295192003250122,
#   0.5295192003250122,
#   0.5295192003250122,
#   0.5459524989128113,
#   0.5295192003250122,
#   0.5380401611328125,
#   0.538648784160614,
#   0.5514302849769592,
#   0.5343883037567139,
#   0.5514302849769592,
#   0.5331710577011108,
#   0.5416920185089111,
#   0.5447352528572083,
#   0.5477784276008606,
#   0.5538648962974548,
#   0.5520389676094055,
#   0.5459524989128113,
#   0.5301278233528137,
#   0.5435179471969604,
#   0.5520389676094055,
#   0.5569080710411072,
#   0.5672550201416016,
#   0.5642117857933044,
#   0.5599513053894043,
#   0.5861229300498962,
#   0.5782105922698975,
#   0.5879488587379456,
#   0.5702982544898987,
#   0.5763846635818481,
#   0.5842970013618469,
#   0.5867316126823425,
#   0.5849056839942932,
#   0.5690809488296509,
#   0.5642117857933044,
#   0.5678636431694031,
#   0.577601969242096,
#   0.5794278979301453,
#   0.5903834700584412,
#   0.592818021774292,
#   0.6055995225906372,
#   0.6001217365264893,
#   0.6019476652145386,
#   0.5958612561225891,
#   0.6019476652145386,
#   0.5976871848106384,
#   0.5989044308662415,
#   0.6025562882423401,
#   0.5952525734901428,
#   0.6055995225906372,
#   0.6043822169303894,
#   0.6025562882423401,
#   0.6025562882423401,
#   0.5958612561225891,
#   0.5952525734901428,
#   0.5958612561225891,
#   0.5909920930862427,
#   0.5934266448020935,
#   0.5976871848106384,
#   0.5964698791503906,
#   0.5922093987464905],
#  'lr': [0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.0019999999,
#   0.0019999999,
#   0.0019999999,
#   0.0019999999,
#   0.0019999999,
#   0.0019999999,
#   0.0019999999,
#   0.0019999999,
#   0.0019999999,
#   0.0019999999,
#   0.0019999999,
#   0.0019999999,
#   0.0019999999,
#   0.00039999996,
#   0.00039999996,
#   0.00039999996,
#   0.00039999996,
#   0.00039999996,
#   0.00039999996,
#   0.00039999996,
#   0.00039999996,
#   0.00039999996,
#   0.00039999996]}

# %%
import pickle
with open('CNNnon_1130.pkl', 'wb') as f:
	pickle.dump(general.history, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(general.history['accuracy'], label='acc')
plt.plot(general.history['val_accuracy'], label='val_acc')
plt.legend(loc='lower right')
plt.title('Accuracy comparison')

plt.subplot(1, 2, 2)
plt.plot(general.history['loss'], label='loss')
plt.plot(general.history['val_loss'], label='val_loss')
plt.legend(loc='upper right')
plt.title('Loss comparison')

plt.show()

# %%
y_test = np.array(y_test).astype(np.float32)
cnn.evaluate(X_test, y_test)
# Out:
# 16/16 [==============================] - 0s 6ms/step - loss: 1.4089 - accuracy: 0.5234
# [1.4088753461837769, 0.5234375]

# %%
import torch
y_test = torch.Tensor(y_test)
y_test = torch.argmax(y_test, dim=1)

# %%
y_pred_enc = cnn.predict(X_test)          # one-hot encoding된 label 예측값
y_pred = [np.argmax(i) for i in y_pred_enc] # label 예측값
matrix = confusion_matrix(y_test, y_pred)
item = {
      0: 'Type 1'
    , 1: 'Type 2'
    , 2: 'Type 3'
}
res = pd.DataFrame(matrix)
res.columns = item.values()
res.index = item.values()
        
res
